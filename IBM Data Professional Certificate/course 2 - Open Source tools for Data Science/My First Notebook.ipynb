# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **DINH Anh-Thi**
#
# PhD in Applied Mathematics. I desire to be a Data Scientist in this year.

# %% [markdown]
# *I am interested in Data Science because it can help us understand the hidden meaning of data and also the way it can help us verify and predict the need of customers and give them the right answer automatically.*

# %% [markdown]
# ### A simple executed code

# %%
t = "I'm DINH Anh-Thi"
print(t)
# Out:
# I'm DINH Anh-Thi

# %% [markdown]
# My simpe info:
#
# - Personal website: [http://dinhanhthi.com](http://dinhanhthi.com)
# - My notes: [http://mynote.dinhanhthi.com](http://mynote.dinhanhthi.com)
#
# > If you can't explain it simply, you don't understand it well enough - Albert Einstein.
#
# ``` python
# t = "I'm DINH Anh-Thi"
# print(t)
# ```
