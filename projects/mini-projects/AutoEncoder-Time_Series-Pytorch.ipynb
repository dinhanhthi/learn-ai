# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import os

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
def plot_signal(df, num_plots=4):
    plt.figure(figsize=(18, 10), dpi= 60)
    sp_idx = 1
    for i in range(num_plots//2 * 2):
        plt.subplot(num_plots//2, 2, sp_idx)
        plt.plot(df.iloc[:,i])
        plt.title(df.columns[i], fontsize=12)
        sp_idx += 1
    plt.tight_layout() # adjust spacing between subplots to minimize the overlaps

# %% [markdown]
# ## Load Wave data

# %%
path_wave = os.path.join('../interview/dataswati/test_python_dataswati_2019/wave_data/')

# %%
def read_wave_txt(path):
    data = []
    with open(path) as f: 
        for line in f: 
            data.append(float(line))
    return data

list_df = []
for name_file in os.listdir(path_wave):
    if int(name_file.split('.')[0].split('_')[1]) < 76:
        data = read_wave_txt(os.path.join(path_wave, name_file))
    
        list_df.append(pd.DataFrame(data, columns=[name_file.split('.')[0]]))
    
df_wave = pd.concat(list_df, axis=1)

# %%
df_wave.head()
# Out:
#    signal_1  signal_10  signal_11  signal_12  signal_13  signal_14  signal_15  \
# 0  4.676030   6.130410   0.521060   1.015464   4.530420   4.986702   3.268506
# 1  5.579902   8.142418   5.033550   7.040959   2.110938   0.184810   6.431391
# 2  4.457226   6.221391   9.300363   4.794966   3.876880   6.336492   4.563317
# 3  3.684351   3.601372   3.428731   5.904889   3.007055   8.051595   6.274882
# 4  6.059252   2.077701   0.343933   0.561882   3.154311   4.433503   3.392108
#
#    signal_16  signal_17  signal_18  ...  signal_69  signal_7  signal_70  \
# 0   1.951665   4.424835   7.629988  ...   5.940402  6.138702   2.804264
# 1   5.602790   5.274199   5.174270  ...   6.428916  3.516436   8.292140
# 2  -1.038347   1.027332   5.652973  ...   9.267523  3.967636   2.560427
# 3   1.216353   4.568939   2.467021  ...   4.981965  5.795101   5.211710
# 4   6.520556   2.920950   0.745330  ...   4.073670  2.261631   1.747242
#
# ...

# %%
plot_signal(df_wave)

# %% [markdown]
# ## Normalize

# %%
scaler = MinMaxScaler()
scaler.fit(df_wave)
df_wave_nor = scaler.transform(df_wave)
df_wave_nor = pd.DataFrame(df_wave_nor, columns = df_wave.columns)

# %%
df_wave_nor.head()
# Out:
#    signal_1  signal_10  signal_11  signal_12  signal_13  signal_14  signal_15  \
# 0  0.734293   0.729118   0.563664   0.519116   0.706804   0.707645   0.646626
# 1  0.772139   0.803847   0.744078   0.736358   0.613584   0.517810   0.764385
# 2  0.725132   0.732498   0.914669   0.655381   0.681624   0.761006   0.694833
# 3  0.692772   0.635187   0.679916   0.695398   0.648111   0.828810   0.758558
# 4  0.792209   0.578596   0.556582   0.502763   0.653784   0.685775   0.651227
#
#    signal_16  signal_17  signal_18  ...  signal_69  signal_7  signal_70  \
# 0   0.571514   0.658627   0.824387  ...   0.712814  0.704046   0.633346
# 1   0.730091   0.689595   0.727584  ...   0.727518  0.603887   0.812523
# 2   0.441650   0.534752   0.746454  ...   0.812955  0.621121   0.625385
# 3   0.539577   0.663881   0.620866  ...   0.683967  0.690922   0.711948
# 4   0.769951   0.603794   0.552998  ...   0.656629  0.555959   0.598835
#
# ...

# %%
plot_signal(df_wave_nor)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-41-84c6fab5f56b> in <module>
# ----> 1 import torch
#       2 import torch.nn as nn
#       3 import torch.nn.functional as F
#
# ModuleNotFoundError: No module named 'torch'
